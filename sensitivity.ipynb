# %%
On calcule la sensibilité 
$$
y'=ay,\. y(O)=1.
$$
Après quelques calculs faciles on obtient 
$$
\fract{\partial y}{\partial a}(t,a) = -te^{-at}.
$$
# Out:
# Variable non définie : On
#
# Variable non définie : $$
# y'=ay,\. y(O)=1.
#   ^^
# Erreur : syntax error, unexpected =, expecting end of file
#
# Variable non définie : $$
#
# Variable non définie : Après
#
# Variable non définie : $$
# \fract{\partial y}{\partial a}(t,a) = -te^{-at}.
# ^^
# Erreur : syntax error, unexpected \
#
# Variable non définie : $$
